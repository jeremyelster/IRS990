# %%
import sys
import urllib.request
import requests
import datetime
import ijson
import pandas as pd
import xmltodict
import flatten_json
import os

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../../')

# %%
import irsparser as irs

# %% [markdown]
# # Main Parser

# %%
client = irs.Client(
    local_data_dir="../../data", ein_filename="eins",
    index_years=[2016, 2017, 2018], save_xml=False,
    parser="base")
# Out:
# Number of EINS: 2147
# Gathered for Filings2016
# Gathered for Filings2017
# Gathered for Filings2018
# Number of Jewish Orgs in Indices: 5153

# %%
client.parse_xmls(add_organization_info=True)
# Out:
# 1000 records processed
# Total Runtime 10.298592 seconds
# 2000 records processed
# Total Runtime 19.633286 seconds
# 3000 records processed
# Total Runtime 30.282277 seconds
# 4000 records processed
# Total Runtime 41.093921 seconds

# %%
df = client.getFinalDF()

# %%
df.head()
# Out:
#          EIN TaxPeriod             DLN FormType          LastUpdated  \
# 0  010267492    201511  93493067000346      990  2016-09-09T23:14:27
# 1  010267492    201611  93493314027057      990  2018-01-18T23:53:03
# 2  010267492    201711  93493030005318      990  2018-03-14T23:04:38
# 3  010406624    201503  93493320093175      990  2016-03-21T17:23:53
# 4  010406624    201603  93493045023697      990  2017-09-13T21:58:58
#
#              ObjectId                        OrganizationName SubmittedOn  \
# 0  201640679349300034                 PORTLAND CHEVRA KADISHA  2016-07-22
# 1  201703149349302705                 PORTLAND CHEVRA KADISHA  2018-01-05
# 2  201810309349300531                 PORTLAND CHEVRA KADISHA  2018-03-08
# 3  201523209349309317  HOLOCAUST HUMAN RIGHTS CENTER OF MAINE  2016-02-04
# 4  201740459349302369  HOLOCAUST HUMAN RIGHTS CENTER OF MAINE  2017-07-27
#
#                                                  URL              Address  \
# 0  https://s3.amazonaws.com/irs-form-990/20164067...   471 Deering Avenue
# 1  https://s3.amazonaws.com/irs-form-990/20170314...   471 Deering Avenue
# 2  https://s3.amazonaws.com/irs-form-990/20181030...   471 Deering Avenue
# 3  https://s3.amazonaws.com/irs-form-990/20152320...  46 University Drive
# 4  https://s3.amazonaws.com/irs-form-990/20174045...  46 University Drive
#
#               ...             TotalLiabilitiesBOY  TotalLiabilitiesEOY  \
# 0             ...                          6121.0              10578.0
# 1             ...                         10578.0              30285.0
# 2             ...                         30285.0              14393.0
# 3             ...                          4194.0               4302.0
# 4             ...                          4302.0               1326.0
#
#    WorkingCapital  returnVersion Deductibility        Foundation Organization  \
# 0        0.000000       2014v6.0    Deductible         509(a)(2)  Corporation
# 1        0.000000       2015v3.0    Deductible         509(a)(2)  Corporation
# 2        0.000000       2016v3.0    Deductible         509(a)(2)  Corporation
# 3        9.008526       2014v5.0    Deductible  170(b)(1)(A)(vi)  Corporation
# 4        8.405485       2015v3.0    Deductible  170(b)(1)(A)(vi)  Corporation
#
#   NTEECode                                     NTEECommonCode  \
# 0     X20Z            Religion-Related, Spiritual Development
# 1     X20Z            Religion-Related, Spiritual Development
# 2     X20Z            Religion-Related, Spiritual Development
# 3     Q700  International, Foreign Affairs and National Se...
# 4     Q700  International, Foreign Affairs and National Se...
#
#           NTEECodeDescription
# 0                   Christian
# 1                   Christian
# 2                   Christian
# 3  International Human Rights
# 4  International Human Rights
#
# [5 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['EIN', 'TaxPeriod', 'DLN', 'FormType', 'LastUpdated', 'ObjectId',
#        'OrganizationName', 'SubmittedOn', 'URL', 'Address', 'BuildTs',
#        'CYRevenuesLessExpenses', 'CYTotalExpenses', 'CYTotalRevenue', 'City',
#        'CountryAbbr', 'GrantDesc', 'GrantMoneyTotal', 'LiabilitiesToAsset',
#        'LoansFromOfficerBOY', 'LoansFromOfficerEOY', 'LoansToOfficerBOY',
#        'LoansToOfficerEOY', 'Mission', 'NotFollowSFAS117',
#        'OfficerCompensationPart7', 'OfficerCompensationPart9', 'OfficerList',
#        'OfficerName', 'OfficerTitle', 'PYRevenuesLessExpenses',
#        'PYTotalExpenses', 'PYTotalRevenue', 'PerparerFirmGrp', 'PreparerDate',
#        'PreparerPersonName', 'ProgramExp', 'ProgramExpenses', 'ReturnTs',
#        'ReturnTypeCd', 'ScheduleA', 'ScheduleI', 'ScheduleJ', 'ScheduleL',
#        'ScheduleO', 'StateAbbr', 'SurplusMargin', 'TaxPeriodBeginDt',
#        'TaxPeriodEndDt', 'TaxYr', 'TotalAssetsBOY', 'TotalAssetsEOY',
#        'TotalEmployee', 'TotalExpenses', 'TotalLiabilitiesBOY',
#        'TotalLiabilitiesEOY', 'WorkingCapital', 'returnVersion',
#        'Deductibility', 'Foundation', 'Organization', 'NTEECode',
#        'NTEECommonCode', 'NTEECodeDescription'],
#       dtype='object')

# %%
client.error_file#['url'].values
# Out:
#                                       error  \
# 0  'NoneType' object has no attribute 'get'
#
#                                                  url   version
# 0  https://s3.amazonaws.com/irs-form-990/20152323...  2012v3.0

# %%
df.to_csv(
    "../../output/forward_jewish_charities_990s_all.csv", header=True, index=False)

# %% [markdown]
# # Create DF_DASH - Dashboard

# %%
dash_cols = [
    # Org Info
    'EIN', 'URL', 'LastUpdated', 'OrganizationName', 'TaxPeriod', 'TaxPeriodBeginDt',
    'TaxPeriodEndDt', 'TaxYr', 'Address', 'City', 'StateAbbr', 'Mission', 'TotalEmployee', "ObjectId",
    'NTEECommonCode', 'Foundation',
    
    # People
    "OfficerName", 'OfficerCompensationPart9', "ScheduleJ",
    
    # Grants and Programs
    "GrantDesc", "GrantMoneyTotal", "ProgramExpenses",
    
    # Money
    "PYTotalRevenue", "CYTotalRevenue",
    "PYRevenuesLessExpenses", "CYRevenuesLessExpenses",
    'TotalAssetsBOY', 'TotalAssetsEOY', 
    'TotalLiabilitiesBOY', "TotalLiabilitiesEOY",
    'TotalExpenses', 'CYTotalExpenses', 'PYTotalExpenses',
    
    # Metrics
    "WorkingCapital", "LiabilitiesToAsset", "SurplusMargin", "ProgramExp",
    
    # Additional
    "ScheduleI", 'ScheduleO', "ScheduleA"]

# %%
df_dash = df.groupby(["EIN", "TaxYr"], as_index=False).last()[dash_cols]#.head()
df_dash.head(1)
# Out:
#          EIN                                                URL  \
# 0  010267492  https://s3.amazonaws.com/irs-form-990/20164067...
#
#            LastUpdated         OrganizationName TaxPeriod TaxPeriodBeginDt  \
# 0  2016-09-09T23:14:27  PORTLAND CHEVRA KADISHA    201511       2014-12-01
#
#   TaxPeriodEndDt TaxYr             Address      City  \
# 0     2015-11-30  2014  471 Deering Avenue  Portland
#
#                          ...                         TotalExpenses  \
# 0                        ...                              188392.0
#
#   CYTotalExpenses PYTotalExpenses WorkingCapital LiabilitiesToAsset  \
# 0        188392.0        201510.0            0.0            0.02373
#
#   SurplusMargin ProgramExp  ScheduleI  \
# 0      0.078664        1.0       None
#
#                                            ScheduleO  \
# 0  {'@documentId': '00000004', '@softwareId': '14...
#
#                                            ScheduleA
# 0  {'@documentId': '00000002', '@softwareId': '14...
#
# [1 rows x 40 columns]

# %%
df_dash.to_csv("../../output/forward_jewish_charities_990s_dash.csv", header=True, index=False)

# %% [markdown]
# # Schedule I - Grants

# %%
for i,r in enumerate(df_dash.columns):
    print(i,r)
# Out:
# 0 EIN
# 1 URL
# 2 LastUpdated
# 3 OrganizationName
# 4 TaxPeriod
# 5 TaxPeriodBeginDt
# 6 TaxPeriodEndDt
# 7 TaxYr
# 8 Address
# 9 City
# 10 StateAbbr
# 11 Mission
# 12 TotalEmployee
# 13 ObjectId
# 14 NTEECommonCode
# 15 Foundation
# 16 OfficerName
# 17 OfficerCompensationPart9
# 18 ScheduleJ
# 19 GrantDesc
# 20 GrantMoneyTotal
# 21 ProgramExpenses
# 22 PYTotalRevenue
# 23 CYTotalRevenue
# 24 PYRevenuesLessExpenses
# 25 CYRevenuesLessExpenses
# 26 TotalAssetsBOY
# 27 TotalAssetsEOY
# 28 TotalLiabilitiesBOY
# 29 TotalLiabilitiesEOY
# 30 TotalExpenses
# 31 CYTotalExpenses
# 32 PYTotalExpenses
# 33 WorkingCapital
# 34 LiabilitiesToAsset
# 35 SurplusMargin
# 36 ProgramExp
# 37 ScheduleI
# 38 ScheduleO
# 39 ScheduleA

# %%
grants = []
errors = 0
df_tmp = df_dash[[
    "EIN", "ObjectId", "OrganizationName", "TaxYr", "Address",
    "City", "StateAbbr", "ScheduleI"]].copy()
for row in df_tmp.itertuples():
    
    if row[8] is not None:
        tmp = {}
        tmp["EIN"] = row[1]
        tmp["ObjectId"] = row[2]
        tmp["OrganizationName"] = row[3]
        tmp["TaxYr"] = row[4]
        tmp["Address"] = row[5]
        tmp["City"] = row[6]
        tmp["StateAbbr"] = row[7]


        d = row[8]
        tbl = d.get("RecipientTable", False)
        if tbl:
            if isinstance(tbl, dict):
                # If its the only element in table, put it in a list to iterate over
                tmp2 = []
                tmp2.append(tbl)
                tbl = tmp2
                errors += 1
            for grant in tbl:
                tmp_grant = flatten_json.flatten(grant)
                
                tmp_grant.update(tmp)
                grants.append(tmp_grant)

# %%
df_grants = pd.DataFrame(grants)

# %%
df_grants.head().T
# Out:
#                                                                                    0  \
# Address                                                            57 Ashmont Street
# CashGrantAmt                                                                   69700
# City                                                                        Portland
# EIN                                                                        010530420
# ForeignAddress_AddressLine1Txt                                                   NaN
# ForeignAddress_AddressLine2Txt                                                   NaN
# ForeignAddress_CityNm                                                            NaN
# ForeignAddress_CountryCd                                                         NaN
# ForeignAddress_ProvinceOrStateNm                                                 NaN
# IRCSectionDesc                                                                   NaN
# NonCashAssistanceAmt                                                             NaN
# NonCashAssistanceDesc                                                            NaN
# ObjectId                                                          201631939349300858
# OrganizationName                            JEWISH COMMUNITY ALLIANCE SOUTHERN MAINE
# PurposeOfGrantTxt                                                    General Support
# RecipientBusinessName_BusinessNameLine1                                          NaN
# RecipientBusinessName_BusinessNameLine1Txt        Jewish Federation of North America
# RecipientBusinessName_BusinessNameLine2Txt                                       NaN
# RecipientEIN                                                               131624240
# StateAbbr                                                                         ME
# TaxYr                                                                           2014
# USAddress_AddressLine1                                                           NaN
# USAddress_AddressLine1Txt                                25 Broadway Street Ste 1700
# USAddress_AddressLine2Txt                                                        NaN
# USAddress_City                                                                   NaN
# USAddress_CityNm                                                            New York
# USAddress_State                                                                  NaN
# USAddress_StateAbbreviationCd                                                     NY
# USAddress_ZIPCd                                                                10004
# USAddress_ZIPCode                                                                NaN
# ValuationMethodUsedDesc                                                          NaN
#
#                                                                                    1  \
# Address                                                            57 Ashmont Street
# CashGrantAmt                                                                   14465
# City                                                                        Portland
# EIN                                                                        010530420
# ForeignAddress_AddressLine1Txt                                                   NaN
# ForeignAddress_AddressLine2Txt                                                   NaN
# ForeignAddress_CityNm                                                            NaN
# ForeignAddress_CountryCd                                                         NaN
# ForeignAddress_ProvinceOrStateNm                                                 NaN
# IRCSectionDesc                                                                   NaN
# NonCashAssistanceAmt                                                             NaN
# NonCashAssistanceDesc                                                            NaN
# ObjectId                                                          201631939349300858
# OrganizationName                            JEWISH COMMUNITY ALLIANCE SOUTHERN MAINE
# PurposeOfGrantTxt                                                     School Support
# RecipientBusinessName_BusinessNameLine1                                          NaN
# RecipientBusinessName_BusinessNameLine1Txt                    Congregation Bet Ha'am
# RecipientBusinessName_BusinessNameLine2Txt                                       NaN
# RecipientEIN                                                               010406924
# StateAbbr                                                                         ME
# TaxYr                                                                           2014
# USAddress_AddressLine1                                                           NaN
# USAddress_AddressLine1Txt                                        81 Westbrook Street
# USAddress_AddressLine2Txt                                                        NaN
# USAddress_City                                                                   NaN
# USAddress_CityNm                                                      South Portland
# USAddress_State                                                                  NaN
# USAddress_StateAbbreviationCd                                                     ME
# USAddress_ZIPCd                                                                04106
# USAddress_ZIPCode                                                                NaN
# ValuationMethodUsedDesc                                                          NaN
#
#                                                                                    2  \
# Address                                                            57 Ashmont Street
# CashGrantAmt                                                                   17450
# City                                                                        Portland
# EIN                                                                        010530420
# ForeignAddress_AddressLine1Txt                                                   NaN
# ForeignAddress_AddressLine2Txt                                                   NaN
# ForeignAddress_CityNm                                                            NaN
# ForeignAddress_CountryCd                                                         NaN
# ForeignAddress_ProvinceOrStateNm                                                 NaN
# IRCSectionDesc                                                                   NaN
# NonCashAssistanceAmt                                                             NaN
# NonCashAssistanceDesc                                                            NaN
# ObjectId                                                          201631939349300858
# OrganizationName                            JEWISH COMMUNITY ALLIANCE SOUTHERN MAINE
# PurposeOfGrantTxt                                                     School Support
# RecipientBusinessName_BusinessNameLine1                                          NaN
# RecipientBusinessName_BusinessNameLine1Txt                          Levey Day School
# RecipientBusinessName_BusinessNameLine2Txt                                       NaN
# RecipientEIN                                                               010285528
# StateAbbr                                                                         ME
# TaxYr                                                                           2014
# USAddress_AddressLine1                                                           NaN
# USAddress_AddressLine1Txt                                         400 Deering Avenue
# USAddress_AddressLine2Txt                                                        NaN
# USAddress_City                                                                   NaN
# USAddress_CityNm                                                            Portland
# USAddress_State                                                                  NaN
# USAddress_StateAbbreviationCd                                                     ME
# USAddress_ZIPCd                                                                04103
# USAddress_ZIPCode                                                                NaN
# ValuationMethodUsedDesc                                                          NaN
#
#                                                                                    3  \
# Address                                                            57 Ashmont Street
# CashGrantAmt                                                                   10817
# City                                                                        Portland
# EIN                                                                        010530420
# ForeignAddress_AddressLine1Txt                                                   NaN
# ForeignAddress_AddressLine2Txt                                                   NaN
# ForeignAddress_CityNm                                                            NaN
# ForeignAddress_CountryCd                                                         NaN
# ForeignAddress_ProvinceOrStateNm                                                 NaN
# IRCSectionDesc                                                                   NaN
# NonCashAssistanceAmt                                                             NaN
# NonCashAssistanceDesc                                                            NaN
# ObjectId                                                          201631939349300858
# OrganizationName                            JEWISH COMMUNITY ALLIANCE SOUTHERN MAINE
# PurposeOfGrantTxt                                                     School Support
# RecipientBusinessName_BusinessNameLine1                                          NaN
# RecipientBusinessName_BusinessNameLine1Txt              Temple Beth El Hebrew School
# RecipientBusinessName_BusinessNameLine2Txt                                       NaN
# RecipientEIN                                                               010228396
# StateAbbr                                                                         ME
# TaxYr                                                                           2014
# USAddress_AddressLine1                                                           NaN
# USAddress_AddressLine1Txt                                         400 Deering Avenue
# USAddress_AddressLine2Txt                                                        NaN
# USAddress_City                                                                   NaN
# USAddress_CityNm                                                            Portland
# USAddress_State                                                                  NaN
# USAddress_StateAbbreviationCd                                                     ME
# USAddress_ZIPCd                                                                04103
# USAddress_ZIPCode                                                                NaN
# ValuationMethodUsedDesc                                                          NaN
#
#                                                                                    4
# Address                                                            57 Ashmont Street
# CashGrantAmt                                                                    5000
# City                                                                        Portland
# EIN                                                                        010530420
# ForeignAddress_AddressLine1Txt                                                   NaN
# ForeignAddress_AddressLine2Txt                                                   NaN
# ForeignAddress_CityNm                                                            NaN
# ForeignAddress_CountryCd                                                         NaN
# ForeignAddress_ProvinceOrStateNm                                                 NaN
# IRCSectionDesc                                                                   NaN
# NonCashAssistanceAmt                                                             NaN
# NonCashAssistanceDesc                                                            NaN
# ObjectId                                                          201631939349300858
# OrganizationName                            JEWISH COMMUNITY ALLIANCE SOUTHERN MAINE
# PurposeOfGrantTxt                                                     School Support
# RecipientBusinessName_BusinessNameLine1                                          NaN
# RecipientBusinessName_BusinessNameLine1Txt                      The Good People Fund
# RecipientBusinessName_BusinessNameLine2Txt                                       NaN
# RecipientEIN                                                               261887249
# StateAbbr                                                                         ME
# TaxYr                                                                           2014
# USAddress_AddressLine1                                                           NaN
# USAddress_AddressLine1Txt                                         384 Wyoming Avenue
# USAddress_AddressLine2Txt                                                        NaN
# USAddress_City                                                                   NaN
# USAddress_CityNm                                                             Milburn
# USAddress_State                                                                  NaN
# USAddress_StateAbbreviationCd                                                     NJ
# USAddress_ZIPCd                                                                07041
# USAddress_ZIPCode                                                                NaN
# ValuationMethodUsedDesc                                                          NaN

# %%
grant_cols = [
    "EIN", "ObjectId", "OrganizationName", "TaxYr", "Address",
    "City", "StateAbbr", "RecipientEIN", "RecipientBusinessName_BusinessNameLine1Txt", "PurposeOfGrantTxt", "CashGrantAmt", 
    'NonCashAssistanceAmt', 'NonCashAssistanceDesc', "IRCSectionDesc", "USAddress_AddressLine1Txt", "USAddress_CityNm", "USAddress_StateAbbreviationCd",
    "ForeignAddress_AddressLine1Txt", "ForeignAddress_CountryCd"
]
df_grants[grant_cols].to_csv("../../output/forward_jewish_grants_to_orgs_all.csv", header=True, index=False)

# %%
# For Dashboard, set ScheduleI to True if exists else False
def scheduleIparser(x):
    if x is None:
        return False
    if x.get("RecipientTable", False):
        return True
    else:
        return False
    
df_dash["ScheduleI"] = df_dash["ScheduleI"].apply(scheduleIparser)

# %% [markdown]
# # Schedule A - OrgType Will be replaced with NTEE Codes eventually
# ## Could be other useful things in ScheduleA that will need to be explored

# %%
all_keys = []
for row in df_dash[["ScheduleA"]].itertuples():
    if row[1] is not None:
        all_keys = set(all_keys).union(list(row[1].keys()))

# %%
org_list = [org for org in list(all_keys) if "Ind" in org]

# %%
org_type = [
    "CollegeOrganizationInd", 'CommunityTrustInd', 'PrivateFoundation509Ind', 'PrivateFoundation170Ind', 
    'MajorityDirTrstSupportedOrgInd',
 'GovernmentalUnitInd',
 'PubliclySupportedOrg509a2Ind',
 'HospitalInd','SupportingOrganization509a3Ind',
 'SchoolInd',
 'PublicOrganization170Ind',
 'ChurchInd'
]
support_type = [
    'SupportingOrgType3FuncIntInd','First5Years170Ind',
 'ThirtyThrPctSuprtTestsCY509Ind','ThirtyThrPctSuprtTestsPY170Ind',
 'SupportingOrgType1Ind','SupportingOrgType2Ind','First5Years509Ind',
 'ThirtyThrPctSuprtTestsPY509Ind','TenPctFactsCrcmstncsTestPYInd',
 'SupportingOrgType3NonFuncInd', 'ThirtyThrPctSuprtTestsCY170Ind',
'TenPctFactsCrcmstncsTestCYInd'
]

irs_written = ['IRSWrittenDeterminationInd']

# %%
org_all = []
df_tmp = df_dash[["EIN", "ObjectId", "OrganizationName", "TaxYr", "StateAbbr", "ScheduleA"]].copy()
        
for row in df_tmp.itertuples():
    org_tmp = {}
    org_tmp["EIN"] = row[1]
    org_tmp["ObjectId"] = row[2]

    if row[6] is not None:
        for org in org_type:
            if row[6].get(org, False) :
                org_tmp["OrgType"] = org
        for org in support_type:
            if row[6].get(org, False) :
                org_tmp["OrgTypeSupport"] = org
        for org in irs_written:
            if row[6].get(org, False) :
                org_tmp["OrgTypeIrsDet"] = org
        org_all.append(org_tmp)
    else:
        org_all.append(org_tmp)

# %%
df_sched_a = pd.DataFrame(org_all)

# %%
df_sched_a.head()
# Out:
#          EIN            ObjectId                       OrgType OrgTypeIrsDet  \
# 0  010267492  201640679349300034  PubliclySupportedOrg509a2Ind           NaN
# 1  010267492  201703149349302705  PubliclySupportedOrg509a2Ind           NaN
# 2  010267492  201810309349300531  PubliclySupportedOrg509a2Ind           NaN
# 3  010406624  201523209349309317      PublicOrganization170Ind           NaN
# 4  010406624  201740459349302369      PublicOrganization170Ind           NaN
#
#                    OrgTypeSupport
# 0  ThirtyThrPctSuprtTestsCY509Ind
# 1  ThirtyThrPctSuprtTestsCY509Ind
# 2  ThirtyThrPctSuprtTestsCY509Ind
# 3   TenPctFactsCrcmstncsTestCYInd
# 4  ThirtyThrPctSuprtTestsCY170Ind

# %% [markdown]
# ## Remove Schedule A from df_dash

# %%
df_dash = pd.merge(df_dash, df_sched_a, on=["EIN", "ObjectId"])

# %%
# Set Schedule A to TrueFalse to indicate if it exists
def scheduleAparser(x):
    if x is None:
        return False
    else:
        return True
df_dash["ScheduleA"] = df_dash["ScheduleA"].apply(scheduleAparser)

# %% [markdown]
# # Schedule J

# %%
all_keys = []
for row in df_dash[['ScheduleJ']].itertuples():
    if row[1] is not None:
        all_keys = set(all_keys).union(list(row[1].keys()))

# %%
officers = []
#errors = 0
df_tmp = df_dash[["EIN", "ObjectId", "OrganizationName", "TaxYr", "StateAbbr", "ScheduleJ"]].copy()
        
for row in df_tmp.itertuples():
    if row[6] is not None:
        
        tmp = {}
        tmp["EIN"] = row[1]
        tmp["ObjectId"] = row[2]
        tmp["OrganizationName"] = row[3]
        tmp["TaxYr"] = row[4]
        tmp["StateAbbr"] = row[5]

        d = row[6]
        
        tmp["SeverancePaymentInd"] = d.get("SeverancePaymentInd", None)
        tmp["TravelForCompanionsInd"] = d.get("TravelForCompanionsInd", None)

        tbl = d.get("RltdOrgOfficerTrstKeyEmplGrp", False)
        if tbl:
            if isinstance(tbl, dict):
                # If its the only element in table, put it in a list to iterate over
                tmp2 = []
                tmp2.append(tbl)
                tbl = tmp2
                errors += 1
            for officer in tbl:
                tmp_officer = flatten_json.flatten(officer)

                tmp_officer.update(tmp)
                officers.append(tmp_officer)
    else:
        
        tmp = {}

# %%
df_officers = pd.DataFrame(officers)

# %%
df_officers.head()
# Out:
#   BaseCompensationFilingOrgAmt BonusFilingOrganizationAmount  \
# 0                       230885                         51000
# 1                       148296                           NaN
# 2                       253970                         55000
# 3                       246127                             0
# 4                       224856                             0
#
#   BonusRelatedOrganizationsAmt BusinessName_BusinessNameLine1  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                            0                            NaN
# 4                            0                            NaN
#
#   BusinessName_BusinessNameLine1Txt BusinessName_BusinessNameLine2  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#   CompReportPrior990FilingOrgAmt CompReportPrior990RltdOrgsAmt  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                              0                             0
# 4                              0                             0
#
#   CompensationBasedOnRltdOrgsAmt DeferredCompRltdOrgsAmt  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                              0                       0
# 4                              0                       0
#
#            ...           OtherCompensationFilingOrgAmt  \
# 0          ...                                     NaN
# 1          ...                                     NaN
# 2          ...                                     NaN
# 3          ...                                       0
# 4          ...                                       0
#
#   OtherCompensationRltdOrgsAmt          PersonNm SeverancePaymentInd  \
# 0                          NaN  JEREMY ROTHSTEIN               false
# 1                          NaN   MICHAEL DICKSON               false
# 2                          NaN     ROZ ROTHSTEIN               false
# 3                            0     ROZ ROTHSTEIN                   0
# 4                            0  JEREMY ROTHSTEIN                   0
#
#   StateAbbr TaxYr           TitleTxt TotalCompensationFilingOrgAmt  \
# 0        CA  2014                COO                        298487
# 1        CA  2014  Director - Israel                        165616
# 2        CA  2014                CEO                        330186
# 3        CA  2016                CEO                        265114
# 4        CA  2016                COO                        232603
#
#   TotalCompensationRltdOrgsAmt TravelForCompanionsInd
# 0                          NaN                   None
# 1                          NaN                   None
# 2                          NaN                   None
# 3                            0                   None
# 4                            0                   None
#
# [5 rows x 26 columns]

# %%
#df_officers.to_csv("output/forward_schedule_j.csv", header=True, index=False)

# %%
# Remove ScheduleJ
def scheduleJparser(x):
    if x is None:
        return False
    if x.get("RltdOrgOfficerTrstKeyEmplGrp", False):
        return True
    else:
        return False
df_dash["ScheduleJ"] = df_dash["ScheduleJ"].apply(scheduleJparser)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-60d1aadbdae4> in <module>()
#       7     else:
#       8         return False
# ----> 9 df_dash["ScheduleJ"] = df_dash["ScheduleJ"].apply(scheduleJparser)
#
# C:\Program Files\Anaconda3\envs\forward\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-86-60d1aadbdae4> in scheduleJparser(x)
#       3     if x is None:
#       4         return False
# ----> 5     if x.get("RltdOrgOfficerTrstKeyEmplGrp", False):
#       6         return True
#       7     else:
#
# AttributeError: 'bool' object has no attribute 'get'

# %% [markdown]
# # Schedule O - Additional Information

# %%
def scheduleOParser(x):
    res_str = ""
    supplInfoDetail = x.get("SupplementalInformationDetail", {})
    if isinstance(supplInfoDetail, dict):
        # If its the only element in table, put it in a list to iterate over
        tmp2 = []
        tmp2.append(supplInfoDetail)
        supplInfoDetail = tmp2
    for detail in supplInfoDetail:
        res = detail.get("ExplanationTxt")
        res_str = " ".join([res_str, res])

    return res_str

# %%
df_dash["ScheduleO"] = df_dash["ScheduleO"].apply(scheduleOParser)

# %%
df_dash.columns
# Out:
# Index(['EIN', 'URL', 'LastUpdated', 'OrganizationName', 'TaxPeriod',
#        'TaxPeriodBeginDt', 'TaxPeriodEndDt', 'TaxYr', 'StateAbbr', 'Mission',
#        'TotalEmployee', 'ObjectId', 'NTEECommonCode', 'Foundation',
#        'OfficerName', 'OfficerCompensationPart9', 'ScheduleJ', 'GrantDesc',
#        'GrantMoneyTotal', 'ProgramExpenses', 'PYTotalRevenue',
#        'CYTotalRevenue', 'PYRevenuesLessExpenses', 'CYRevenuesLessExpenses',
#        'TotalAssetsBOY', 'TotalAssetsEOY', 'TotalLiabilitiesBOY',
#        'TotalLiabilitiesEOY', 'TotalExpenses', 'CYTotalExpenses',
#        'PYTotalExpenses', 'WorkingCapital', 'LiabilitiesToAsset',
#        'SurplusMargin', 'ProgramExp', 'ScheduleI', 'ScheduleO', 'ScheduleA',
#        'OrgType', 'OrgTypeIrsDet', 'OrgTypeSupport'],
#       dtype='object')

# %%
df_dash.to_csv("output/forward_dashboard_final_v0.csv", header=True, index=False)
